# %%
from telenvi import raster_tools as rt

# %%
"""
Le module raster_tools du package telenvi dispose de fonctions simples destinées à traiter des objets de type osgeo.gdal.dataset
"""
pass

# %%
# Get metadata
help(rt.getBandsRowsColsFromDs)
help(rt.getDsCoordsExtent)
help(rt.getDsOriginPoint)
help(rt.getDsPixelSize)
help(rt.getDsProjection)

# Crop)
help(rt.cropDsFromVector)
help(rt.cropDsFromIndex)
help(rt.cropDsFromRaster)

# Resample)
help(rt.resizeDs)

# Merge)
help(rt.mergeDs)

# Création)
help(rt.makeDs)

# Shift son origine géographique
help(rt.shiftDsOriginPoint)

# Stack)
help(rt.stackDs)
# Out:
# Help on function getBandsRowsColsFromDs in module telenvi.raster_tools:
#
# getBandsRowsColsFromDs(ds)
#     ds : osgeo.gdal.Dataset or str
#         if str, convert into osgeo.gdal.Dataset with gdal.Open()
#
#     send a tuple (numBands, numRows, numCols)
#
# Help on function getDsCoordsExtent in module telenvi.raster_tools:
#
# getDsCoordsExtent(ds)
#     ds : osgeo.gdal.Dataset or str
#         if str, convert into osgeo.gdal.Dataset with gdal.Open()
#
#     send a tuple (xMin, yMin, xMax, yMax)
#
# Help on function getDsOriginPoint in module telenvi.raster_tools:
#
# getDsOriginPoint(ds)
#     ds : osgeo.gdal.Dataset or str
#         if str, convert into osgeo.gdal.Dataset with gdal.Open()
#
#     send a tuple (xMin,)
#
# Help on function getDsPixelSize in module telenvi.raster_tools:
#
# getDsPixelSize(ds)
#     ds : osgeo.gdal.Dataset or str
#         if str, convert into osgeo.gdal.Dataset with gdal.Open()
#
#     send a tuple (pixelSizeX, pixelSizeY)
#
# ...
